# %% [markdown]
# # MODELOS

# %%
from modelling_utils.preprocessing import get_abt_estacoes_vizinhas
from training_utils import train_model
import duckdb
from xgboost import XGBRegressor,XGBClassifier
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

modelling_conn = duckdb.connect('modelling_db')
abt_estacoes_vizinhas = get_abt_estacoes_vizinhas(modelling_conn=modelling_conn,abt_estacoes_vizinhas_table_name='abt_estacoes_3_vizinhas')
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
for i in range(1,13):
    print(f"Vizinha {i}: {len(abt_estacoes_vizinhas.loc[~abt_estacoes_vizinhas[f'vl_precipitacao_vizinha_{i}'].isna()])/len(abt_estacoes_vizinhas):.2%} de dados disponíveis para modelagem.")
# Out:
# Vizinha 1: 98.58% de dados disponíveis para modelagem.
# Vizinha 2: 92.90% de dados disponíveis para modelagem.
# Vizinha 3: 73.38% de dados disponíveis para modelagem.
# Vizinha 4: 85.44% de dados disponíveis para modelagem.
# Vizinha 5: 84.75% de dados disponíveis para modelagem.
# Vizinha 6: 83.54% de dados disponíveis para modelagem.
# Vizinha 7: 82.25% de dados disponíveis para modelagem.
# Vizinha 8: 80.56% de dados disponíveis para modelagem.
# Vizinha 9: 80.29% de dados disponíveis para modelagem.
# Vizinha 10: 79.07% de dados disponíveis para modelagem.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vl_precipitacao_vizinha_11'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 for i in range(1,13):
# ----> 2     print(f"Vizinha {i}: {len(abt_estacoes_vizinhas.loc[~abt_estacoes_vizinhas[f'vl_precipitacao_vizinha_{i}'].isna()])/len(abt_estacoes_vizinhas):.2%} de dados disponíveis para modelagem.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'vl_precipitacao_vizinha_11'

# %% [markdown]
# ## Modelo 1

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=1,
    usar_n_estacoes_vizinhas=0,
    zero_undersampling_ratio=None,
    smote_oversampling=False,
    use_bi_model=False,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 2

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=2,
    usar_n_estacoes_vizinhas=1,
    zero_undersampling_ratio=None,
    smote_oversampling=False,
    use_bi_model=False,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 3

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=3,
    usar_n_estacoes_vizinhas=1,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=False,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 4

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=4,
    usar_n_estacoes_vizinhas=1,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 5

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=5,
    usar_n_estacoes_vizinhas=1,
    zero_undersampling_ratio=None,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 6

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=6,
    usar_n_estacoes_vizinhas=1,
    zero_undersampling_ratio=2,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 7

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=7,
    usar_n_estacoes_vizinhas=1,
    zero_undersampling_ratio=5,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 8

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=8,
    usar_n_estacoes_vizinhas=2,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 9

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=9,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 10

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=10,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=None,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 11

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=11,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.25,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 12

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=12,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.75,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)
# Out:
# Modelo 12 | XGBRegressor | 3 estações | Bi-model
# Preparando dados:   0%|          | 0/2 [00:00<?, ?it/s]
# 📊 Iniciando processamento com 3848632 registros...
# 🏭 Dataset base criado com 40 colunas
# 🌐 Incluindo dados de 3 estação(ões) vizinha(s)...
# Adicionando estações vizinhas:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ Dataset expandido para 55 colunas
# 🔄 Realizando partição temporal (70.0% treino)...
# 📈 Treino: 2693414 registros | Teste: 1155218 registros
# ⚖️  Aplicando undersampling com ratio 1...
#     💡 Isso significa: 1 zeros para cada 1 não-zero
# 📊 Undersampling de zeros:
#    • Não-zeros disponíveis: 1004531
#    • Zeros disponíveis: 1688883
#    • Zero ratio: 1 (zeros por não-zero)
#    • Zeros desejados: 1004531
#    • Zeros finais: 1004531
# 📉 Antes: 1,688,883 zeros, 1,004,531 não-zeros
# 📊 Depois: 1,004,953 zeros, 1,004,109 não-zeros
# 📈 Ratio real: 1.00 | Tamanho: 2693414 → 2009062
#
# 📋 Resumo final:
#    • Features de treino: (2009062, 54)
#    • Features de teste: (1155218, 54)
#    • Target treino - valores únicos: 105213
#    • Target teste - valores únicos: 74127
#
# 📊 Estatísticas do target após processamento:
#    • Treino - Média: 5.078, Mediana: 0.000
#    • Teste  - Média: 3.841, Mediana: 0.000
#    • Zeros no treino: 1,004,953 (50.0%)
#    • Zeros no teste: 722,525 (62.5%)
# 📊 Iniciando processamento com 18194966 registros...
# 🏭 Dataset base criado com 40 colunas
# 🌐 Incluindo dados de 3 estação(ões) vizinha(s)...
# Adicionando estações vizinhas:   0%|          | 0/3 [00:00<?, ?it/s]
# ⚠️  Aviso: Colunas não encontradas para estação vizinha 1: ['vl_correlacao_estacao_vizinha_1', 'pct_intersecao_precipitacao_vizinha_1', 'vl_distancia_km_vizinha_1', 'vl_prioridade_vizinha_1', 'vl_precipitacao_vizinha_1']
# ⚠️  Aviso: Colunas não encontradas para estação vizinha 2: ['vl_correlacao_estacao_vizinha_2', 'pct_intersecao_precipitacao_vizinha_2', 'vl_distancia_km_vizinha_2', 'vl_prioridade_vizinha_2', 'vl_precipitacao_vizinha_2']
# ⚠️  Aviso: Colunas não encontradas para estação vizinha 3: ['vl_correlacao_estacao_vizinha_3', 'pct_intersecao_precipitacao_vizinha_3', 'vl_distancia_km_vizinha_3', 'vl_prioridade_vizinha_3', 'vl_precipitacao_vizinha_3']
# ✅ Dataset expandido para 40 colunas
# 🔄 Realizando partição temporal (70.0% treino)...
# 📈 Treino: 12734467 registros | Teste: 5460499 registros
# ⚖️  Aplicando undersampling com ratio 1...
#     💡 Isso significa: 1 zeros para cada 1 não-zero
# 📊 Undersampling de zeros:
#    • Não-zeros disponíveis: 4101340
#    • Zeros disponíveis: 8633127
#    • Zero ratio: 1 (zeros por não-zero)
#    • Zeros desejados: 4101340
#    • Zeros finais: 4101340
# 📉 Antes: 8,633,127 zeros, 4,101,340 não-zeros
# 📊 Depois: 4,099,870 zeros, 4,102,810 não-zeros
# 📈 Ratio real: 1.00 | Tamanho: 12734467 → 8202680
#
# 📋 Resumo final:
#    • Features de treino: (8202680, 39)
#    • Features de teste: (5460499, 39)
#    • Target treino - valores únicos: 174584
#    • Target teste - valores únicos: 121810
#
# 📊 Estatísticas do target após processamento:
#    • Treino - Média: 5.779, Mediana: 0.100
#    • Teste  - Média: 3.717, Mediana: 0.000
#    • Zeros no treino: 4,099,870 (50.0%)
#    • Zeros no teste: 3,700,979 (67.8%)
# Treinando modelos:   0%|          | 0/2 [00:00<?, ?it/s]
# ✅ Modelo 12 salvo

# %% [markdown]
# ## Modelo 13

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=13,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.85,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 14

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=14,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.95,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %% [markdown]
# ## Modelo 15

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=15,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=2,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.75,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)
# Out:
# Modelo 15 | XGBRegressor | 3 estações | Bi-model
# Preparando dados:   0%|          | 0/2 [00:00<?, ?it/s]
# 📊 Iniciando processamento com 3848632 registros...
# 🏭 Dataset base criado com 40 colunas
# 🌐 Incluindo dados de 3 estação(ões) vizinha(s)...
# Adicionando estações vizinhas:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ Dataset expandido para 55 colunas
# 🔄 Realizando partição temporal (70.0% treino)...
# 📈 Treino: 2693414 registros | Teste: 1155218 registros
# ⚖️  Aplicando undersampling com ratio 2...
#     💡 Isso significa: 2 zeros para cada 1 não-zero
# 📊 Undersampling de zeros:
#    • Não-zeros disponíveis: 1004531
#    • Zeros disponíveis: 1688883
#    • Zero ratio: 2 (zeros por não-zero)
#    • Zeros desejados: 2009062
#    • Zeros finais: 1688883
# 📉 Antes: 1,688,883 zeros, 1,004,531 não-zeros
# 📊 Depois: 1,688,806 zeros, 1,004,608 não-zeros
# 📈 Ratio real: 1.68 | Tamanho: 2693414 → 2693414
#
# 📋 Resumo final:
#    • Features de treino: (2693414, 54)
#    • Features de teste: (1155218, 54)
#    • Target treino - valores únicos: 105749
#    • Target teste - valores únicos: 74127
#
# 📊 Estatísticas do target após processamento:
#    • Treino - Média: 3.797, Mediana: 0.000
#    • Teste  - Média: 3.841, Mediana: 0.000
#    • Zeros no treino: 1,688,806 (62.7%)
#    • Zeros no teste: 722,525 (62.5%)
# 📊 Iniciando processamento com 18194966 registros...
# 🏭 Dataset base criado com 40 colunas
# 🌐 Incluindo dados de 3 estação(ões) vizinha(s)...
# Adicionando estações vizinhas:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ Dataset expandido para 55 colunas
# 🔄 Realizando partição temporal (70.0% treino)...
# 📈 Treino: 12734467 registros | Teste: 5460499 registros
# ⚖️  Aplicando undersampling com ratio 2...
#     💡 Isso significa: 2 zeros para cada 1 não-zero
# 📊 Undersampling de zeros:
#    • Não-zeros disponíveis: 4101340
#    • Zeros disponíveis: 8633127
#    • Zero ratio: 2 (zeros por não-zero)
#    • Zeros desejados: 8202680
#    • Zeros finais: 8202680
# 📉 Antes: 8,633,127 zeros, 4,101,340 não-zeros
# 📊 Depois: 8,202,850 zeros, 4,101,170 não-zeros
# 📈 Ratio real: 2.00 | Tamanho: 12734467 → 12304020
#
# 📋 Resumo final:
#    • Features de treino: (12304020, 54)
#    • Features de teste: (5460499, 54)
#    • Target treino - valores únicos: 174731
#    • Target teste - valores únicos: 121810
#
# 📊 Estatísticas do target após processamento:
#    • Treino - Média: 3.852, Mediana: 0.000
#    • Teste  - Média: 3.717, Mediana: 0.000
#    • Zeros no treino: 8,202,850 (66.7%)
#    • Zeros no teste: 3,700,979 (67.8%)
# Treinando modelos:   0%|          | 0/2 [00:00<?, ?it/s]
# ✅ Modelo 15 salvo

# %% [markdown]
# ## Modelo 16

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=16,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=None,
    smote_oversampling=True,
    use_bi_model=True,
    threshold_prioridade=0.75,
    percent_datetime_partitioning_split=0.05,
    truncate_to_non_negative_target=True,
    smote_constraint_columns='dt_medicao',
    smote_explanatory_variables=['latitude','longitude'],
    smote_pct_oversampling=0.01
    )

# %% [markdown]
# ## Modelo 17

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=17,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=2,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.75,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True,
    classifier_model=XGBClassifier,
    classifier_thresholds=[1,10])

# %% [markdown]
# ## Modelo 18

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=18,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=2,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.75,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True,
    classifier_model=XGBClassifier,
    classifier_thresholds=[0.5,3,20])
# Out:
# Modelo 18 | XGBRegressor | 3 estações | Bi-model + Híbrido
#   Classificador: XGBClassifier | Thresholds: [0.5, 3.0, 20.0]
# Preparando dados:   0%|          | 0/2 [00:00<?, ?it/s]
# 📊 Iniciando processamento com 3848632 registros...
# 🏭 Dataset base criado com 40 colunas
# 🌐 Incluindo dados de 3 estação(ões) vizinha(s)...
# Adicionando estações vizinhas:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ Dataset expandido para 55 colunas
# 🔄 Realizando partição temporal (70.0% treino)...
# 📈 Treino: 2693414 registros | Teste: 1155218 registros
# ⚖️  Aplicando undersampling com ratio 2...
#     💡 Isso significa: 2 zeros para cada 1 não-zero
# 📊 Undersampling de zeros:
#    • Não-zeros disponíveis: 1004531
#    • Zeros disponíveis: 1688883
#    • Zero ratio: 2 (zeros por não-zero)
#    • Zeros desejados: 2009062
#    • Zeros finais: 1688883
# 📉 Antes: 1,688,883 zeros, 1,004,531 não-zeros
# 📊 Depois: 1,688,169 zeros, 1,005,245 não-zeros
# 📈 Ratio real: 1.68 | Tamanho: 2693414 → 2693414
#
# 📋 Resumo final:
#    • Features de treino: (2693414, 54)
#    • Features de teste: (1155218, 54)
#    • Target treino - valores únicos: 105562
#    • Target teste - valores únicos: 74127
#
# 📊 Estatísticas do target após processamento:
#    • Treino - Média: 3.801, Mediana: 0.000
#    • Teste  - Média: 3.841, Mediana: 0.000
#    • Zeros no treino: 1,688,169 (62.7%)
#    • Zeros no teste: 722,525 (62.5%)
# 📊 Iniciando processamento com 18194966 registros...
# 🏭 Dataset base criado com 40 colunas
# 🌐 Incluindo dados de 3 estação(ões) vizinha(s)...
# Adicionando estações vizinhas:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ Dataset expandido para 55 colunas
# 🔄 Realizando partição temporal (70.0% treino)...
# 📈 Treino: 12734467 registros | Teste: 5460499 registros
# ⚖️  Aplicando undersampling com ratio 2...
#     💡 Isso significa: 2 zeros para cada 1 não-zero
# 📊 Undersampling de zeros:
#    • Não-zeros disponíveis: 4101340
#    • Zeros disponíveis: 8633127
#    • Zero ratio: 2 (zeros por não-zero)
#    • Zeros desejados: 8202680
#    • Zeros finais: 8202680
# 📉 Antes: 8,633,127 zeros, 4,101,340 não-zeros
# 📊 Depois: 8,203,781 zeros, 4,100,239 não-zeros
# 📈 Ratio real: 2.00 | Tamanho: 12734467 → 12304020
#
# 📋 Resumo final:
#    • Features de treino: (12304020, 54)
#    • Features de teste: (5460499, 54)
#    • Target treino - valores únicos: 174786
#    • Target teste - valores únicos: 121810
#
# 📊 Estatísticas do target após processamento:
#    • Treino - Média: 3.846, Mediana: 0.000
#    • Teste  - Média: 3.717, Mediana: 0.000
#    • Zeros no treino: 8,203,781 (66.7%)
#    • Zeros no teste: 3,700,979 (67.8%)
# Treinando modelos:   0%|          | 0/2 [00:00<?, ?it/s]
#   ✓ [com_vizinha] Bin 0 [0, 0.5): 1860613 amostras de treino
#   ✓ [com_vizinha] Bin 1 [0.5, 3.0): 263732 amostras de treino
#   ✓ [com_vizinha] Bin 2 [3.0, 20.0): 406494 amostras de treino
#   ✓ [com_vizinha] Bin 3 [20.0, ∞): 162575 amostras de treino
#   ✓ [sem_vizinha] Bin 0 [0, 0.5): 8728868 amostras de treino
#   ✓ [sem_vizinha] Bin 1 [0.5, 3.0): 981227 amostras de treino
#   ✓ [sem_vizinha] Bin 2 [3.0, 20.0): 1811507 amostras de treino
#   ✓ [sem_vizinha] Bin 3 [20.0, ∞): 782418 amostras de treino
# ✅ Modelo 18 salvo

# %% [markdown]
# ## Modelo 19

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=19,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=2,
    smote_oversampling=False,
    use_bi_model=True,
    threshold_prioridade=0.75,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True,
    classifier_model=XGBClassifier,
    classifier_thresholds=[0.5,3,10,20])
# Out:
# Modelo 19 | XGBRegressor | 3 estações | Bi-model + Híbrido
#   Classificador: XGBClassifier | Thresholds: [0.5, 3.0, 10.0, 20.0]
# Preparando dados:   0%|          | 0/2 [00:00<?, ?it/s]
# 📊 Iniciando processamento com 3848632 registros...
# 🏭 Dataset base criado com 40 colunas
# 🌐 Incluindo dados de 3 estação(ões) vizinha(s)...
# Adicionando estações vizinhas:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ Dataset expandido para 55 colunas
# 🔄 Realizando partição temporal (70.0% treino)...
# 📈 Treino: 2693414 registros | Teste: 1155218 registros
# ⚖️  Aplicando undersampling com ratio 2...
#     💡 Isso significa: 2 zeros para cada 1 não-zero
# 📊 Undersampling de zeros:
#    • Não-zeros disponíveis: 1004531
#    • Zeros disponíveis: 1688883
#    • Zero ratio: 2 (zeros por não-zero)
#    • Zeros desejados: 2009062
#    • Zeros finais: 1688883
# 📉 Antes: 1,688,883 zeros, 1,004,531 não-zeros
# 📊 Depois: 1,689,798 zeros, 1,003,616 não-zeros
# 📈 Ratio real: 1.68 | Tamanho: 2693414 → 2693414
#
# 📋 Resumo final:
#    • Features de treino: (2693414, 54)
#    • Features de teste: (1155218, 54)
#    • Target treino - valores únicos: 105740
#    • Target teste - valores únicos: 74127
#
# 📊 Estatísticas do target após processamento:
#    • Treino - Média: 3.801, Mediana: 0.000
#    • Teste  - Média: 3.841, Mediana: 0.000
#    • Zeros no treino: 1,689,798 (62.7%)
#    • Zeros no teste: 722,525 (62.5%)
# 📊 Iniciando processamento com 18194966 registros...
# 🏭 Dataset base criado com 40 colunas
# 🌐 Incluindo dados de 3 estação(ões) vizinha(s)...
# Adicionando estações vizinhas:   0%|          | 0/3 [00:00<?, ?it/s]
# ✅ Dataset expandido para 55 colunas
# 🔄 Realizando partição temporal (70.0% treino)...
# 📈 Treino: 12734467 registros | Teste: 5460499 registros
# ⚖️  Aplicando undersampling com ratio 2...
#     💡 Isso significa: 2 zeros para cada 1 não-zero
# 📊 Undersampling de zeros:
#    • Não-zeros disponíveis: 4101340
#    • Zeros disponíveis: 8633127
#    • Zero ratio: 2 (zeros por não-zero)
#    • Zeros desejados: 8202680
#    • Zeros finais: 8202680
# 📉 Antes: 8,633,127 zeros, 4,101,340 não-zeros
# 📊 Depois: 8,202,222 zeros, 4,101,798 não-zeros
# 📈 Ratio real: 2.00 | Tamanho: 12734467 → 12304020
#
# 📋 Resumo final:
#    • Features de treino: (12304020, 54)
#    • Features de teste: (5460499, 54)
#    • Target treino - valores únicos: 174654
#    • Target teste - valores únicos: 121810
#
# 📊 Estatísticas do target após processamento:
#    • Treino - Média: 3.844, Mediana: 0.000
#    • Teste  - Média: 3.717, Mediana: 0.000
#    • Zeros no treino: 8,202,222 (66.7%)
#    • Zeros no teste: 3,700,979 (67.8%)
# Treinando modelos:   0%|          | 0/2 [00:00<?, ?it/s]
#   ✓ [com_vizinha] Bin 0 [0, 0.5): 1861874 amostras de treino
#   ✓ [com_vizinha] Bin 1 [0.5, 3.0): 262626 amostras de treino
#   ✓ [com_vizinha] Bin 2 [3.0, 10.0): 254481 amostras de treino
#   ✓ [com_vizinha] Bin 3 [10.0, 20.0): 152449 amostras de treino
#   ✓ [com_vizinha] Bin 4 [20.0, ∞): 161984 amostras de treino
#   ✓ [sem_vizinha] Bin 0 [0, 0.5): 8728434 amostras de treino
#   ✓ [sem_vizinha] Bin 1 [0.5, 3.0): 980935 amostras de treino
#   ✓ [sem_vizinha] Bin 2 [3.0, 10.0): 1103660 amostras de treino
#   ✓ [sem_vizinha] Bin 3 [10.0, 20.0): 709680 amostras de treino
#   ✓ [sem_vizinha] Bin 4 [20.0, ∞): 781311 amostras de treino
# ✅ Modelo 19 salvo

# %% [markdown]
# ## Modelo 20

# %%
model,comparison = train_model(
    abt_estacoes_vizinhas,
    Model=XGBRegressor,
    model_number=3,
    usar_n_estacoes_vizinhas=3,
    zero_undersampling_ratio=1,
    smote_oversampling=False,
    use_bi_model=False,
    threshold_prioridade=0.5,
    percent_datetime_partitioning_split=0.7,
    truncate_to_non_negative_target=True)

# %%
# Testar usar o predict_proba pra ponderar o resultado dos regressores (isto não muda o treinamento, só a predição)
# Na classe acima de 0.5, tentar separar os bins para ter a mesma volumetria de dados em cada bin (4 classes: 0, 2 com mesmo volume e casos raros, como 20mm+)
# classifier_thresholds = [0.5,1,20]

# %% [markdown]
# # COMPARAÇÕES

# %%
from comparison_utils import plot_model_metrics,import_model_and_comparison,compute_metrics,plot_metrica_heatmap,plot_feature_importance
import pandas as pd

# Parâmetros de métricas
relative_error_threshold = 0.2
absolute_error_threshold_PCC = 5
absolute_error_threshold_PMC = 10
min_sem_chuva = 1
min_relevancia = 0.5
beta = 1
minimo_muita_chuva = 20

# %% [markdown]
# ## Métricas Gerais

# %%
model_numbers = [12,15,17]
# model_numbers = [8,9,10,11,12,13,14,15,16]
# model_numbers = [1]
models,comparisons,metrics = {},{},{}
for model_number in model_numbers:
    model_path,comparison_path = f'models/model_{model_number}.pkl',f'comparisons/comparison_{model_number}.pkl'
    models[model_number],comparisons[model_number] = import_model_and_comparison(model_path,comparison_path)
    if type(models[model_number]) == dict:
        comparisons[model_number] = pd.concat(comparisons[model_number].values())

    comparisons[model_number]['model'] = f'model_{model_number}'
    metrics[model_number] = compute_metrics(comparisons[model_number]['y_test'],comparisons[model_number]['y_pred'],relative_error_threshold,absolute_error_threshold_PCC,absolute_error_threshold_PMC,min_sem_chuva,min_relevancia,beta,minimo_muita_chuva)
metrics_df = pd.DataFrame.from_dict(metrics,orient='index').reset_index(names=['model_number'])

# %%
# prob bin 0 -> 0.05
# prob bin 1 -> 0.8
# prob bin 2 -> 0.15

# predt model 0 * prob bin 0
# predt model 1 * prob bin 1
# ppredt model 2 * prob bin 2

# %%
plot_model_metrics(metrics_df, ['R2', 'RMSE','PSC_A','PCC_A','PMC_A','precision','recall','F1-Score'])

# %%
plot_feature_importance(models[15]['com_vizinha'],
                        title='Top 10 Variables - Feature Importance of Specialized Model', figsize=(9,3),
                        xlabel='Importance', ylabel='Explanatory Variables',replace=True)
# Out:
# C:\Users\Mateus Santos Rochas\AppData\Local\Temp\ipykernel_17984\3803211204.py:333: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
plot_feature_importance(models[15]['sem_vizinha'],
                        title='Top 10 Variables - Feature Importance of General Model', figsize=(9,3),
                        xlabel='Importance', ylabel='Explanatory Variables',replace=True)
# Out:
# C:\Users\Mateus Santos Rochas\AppData\Local\Temp\ipykernel_17984\3803211204.py:333: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
models[15]['sem_vizinha'].feature_names_in_
# Out:
# array(['latitude', 'longitude', 'vl_declividade', 'vl_altitude',
#        'vl_distancia_oceano', 'vl_aspecto_relevo',
#        'vl_temperatura_maxima', 'vl_temperatura_media',
#        'vl_temperatura_minima', 'vl_umidade_relativa_maxima',
#        'vl_umidade_relativa_media', 'vl_umidade_relativa_minima',
#        'vl_velocidade_vento_2m_maxima', 'vl_velocidade_vento_2m_media',
#        'vl_velocidade_vento_10m_media', 'vl_precipitacao_chirps',
#        'vl_precipitacao_cpc', 'vl_temperatura_maxima_cpc',
#        'vl_temperatura_minima_cpc', 'vl_precipitacao_gpm_final_run',
#        'vl_precipitacao_gpm_late_run', 'vl_precipitacao_power',
#        'vl_temperatura_maxima_2m_K_power',
#        'vl_temperatura_media_2m_K_power',
#        'vl_temperatura_minima_2m_K_power', 'vl_umidade_relativa_2m_power',
#        'vl_pressao_nivel_superficie_power', 'vl_irradiancia_allsky_power',
#        'vl_direcao_vento_10m_power', 'vl_direcao_vento_2m_power',
#        'vl_temperatura_orvalho_2m_K_power', 'vl_vento_10m_power',
#        'vl_vento_medio_2m_power', 'vl_vento_maximo_2m_power',
#        'vl_vento_maximo_10m_power', 'dt_medicao_mes', 'dt_medicao_ano',
#        'vl_correlacao_estacao_vizinha_1',
#        'pct_intersecao_precipitacao_vizinha_1',
#        'vl_distancia_km_vizinha_1', 'vl_prioridade_vizinha_1',
#        'vl_precipitacao_vizinha_1', 'vl_correlacao_estacao_vizinha_2',
#        'pct_intersecao_precipitacao_vizinha_2',
#        'vl_distancia_km_vizinha_2', 'vl_prioridade_vizinha_2',
#        'vl_precipitacao_vizinha_2', 'vl_correlacao_estacao_vizinha_3',
#        'pct_intersecao_precipitacao_vizinha_3',
#        'vl_distancia_km_vizinha_3', 'vl_prioridade_vizinha_3',
#        'vl_precipitacao_vizinha_3'], dtype='<U37')

# %% [markdown]
# ## Comparando com os produtos

# %%
import duckdb
import seaborn as sns
modelling_conn = duckdb.connect('modelling_db')

# %%
model_numbers_produtos = [15]

precipitacao_produtos = modelling_conn.execute(
"""
SELECT 
    vl_precipitacao
    ,vl_precipitacao_vizinha_1
    ,vl_prioridade_vizinha_1
    ,CASE WHEN vl_precipitacao_chirps > 200 THEN 200 ELSE vl_precipitacao_chirps END AS vl_precipitacao_chirps
    ,CASE WHEN vl_precipitacao_cpc < 0 THEN 0 ELSE vl_precipitacao_cpc END AS vl_precipitacao_cpc
    ,CASE WHEN vl_precipitacao_gpm_final_run > 200 THEN 200 ELSE vl_precipitacao_gpm_final_run END AS vl_precipitacao_gpm_final_run
    ,CASE WHEN vl_precipitacao_gpm_late_run > 200 THEN 200 ELSE vl_precipitacao_gpm_late_run END AS vl_precipitacao_gpm_late_run
    ,vl_precipitacao_power 
FROM abt_estacoes_3_vizinhas""").fetch_df()

produtos = ['chirps','cpc','gpm_final_run','gpm_late_run','power','vizinha_1']
precipitacao_produto = {produto:precipitacao_produtos[['vl_precipitacao',f'vl_precipitacao_{produto}']].dropna() for produto in produtos}

produtos_metrics = {produto:compute_metrics(precipitacao_produto[produto]['vl_precipitacao'],precipitacao_produto[produto][f'vl_precipitacao_{produto}']) for produto in produtos}
for model_number in model_numbers_produtos:
    produtos_metrics[f'Modelo'] = metrics[model_number]

produtos_metrics_df = pd.DataFrame.from_dict(produtos_metrics,orient='index').reset_index(names=['model_number'])
for produto in produtos:
    produtos_metrics_df.loc[produtos_metrics_df['R2']<0,'R2']=0
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
precipitacao_produtos['erro_abs'] = abs(precipitacao_produtos['vl_precipitacao'] - precipitacao_produtos['vl_precipitacao_vizinha_1'])
precipitacao_produtos['erro_pct'] = abs(precipitacao_produtos['vl_precipitacao'] - precipitacao_produtos['vl_precipitacao_vizinha_1']) / (precipitacao_produtos['vl_precipitacao'] + 0.1)

# %%
sns.scatterplot(data=precipitacao_produtos.loc[precipitacao_produtos['erro_abs']<=100].iloc[:10000],x='erro_abs',y='vl_prioridade_vizinha_1',alpha=0.3,s=2)
# Out:
# <Axes: xlabel='erro_abs', ylabel='vl_prioridade_vizinha_1'>

# %%
# Out:
#     model_number  precision    recall  F1-Score       RMSE        R2  \
# 0         chirps   0.114363  0.102726  0.108232  10.668147  0.000000
# 1            cpc   0.209131  0.131592  0.161539   8.767949  0.288261
# 2  gpm_final_run   0.006428  0.047188  0.011315  60.466628  0.000000
# 3   gpm_late_run   0.008659  0.058521  0.015086  59.072463  0.000000
# 4          power   0.120986  0.061619  0.081652   9.903875  0.093406
# 5     neighbor_1   0.268081  0.279640  0.273739   8.688935  0.301707
# 6         Modelo   0.390336  0.271225  0.320058   6.644009  0.594721
#
#          MAE      PSC_A      PCC_A      PMC_A
# 0   4.467259  86.802120  44.630281  20.263101
# 1   3.418785  84.244933  53.610008  24.782133
# 2  28.418519  73.484828  24.860035   6.529959
# 3  26.691317  74.893699  25.833057   8.070818
# 4   4.185496  73.014047  50.553485  15.299255
# 5   2.998597  92.524823  59.993571  37.819015
# 6   2.547403  82.668627  65.963572  42.811096

# %%
plot_model_metrics(produtos_metrics_df.replace('vizinha_1','neighbor_1').replace('Modelo','Model'),
                   ['R2', 'RMSE','PSC_A','PCC_A','PMC_A','precision','recall','F1-Score'],metrics_per_row=3,xlabel='Model')

# %% [markdown]
# ## Análise por estações

# %%
estacoes = comparisons[1]['id_estacao'].unique()
dim_lat_lon = comparisons[1][['id_estacao','latitude','longitude']].drop_duplicates()

comparisons_estacoes = {
    model_number:{
        id_estacao:comparisons[model_number].loc[comparisons[model_number]['id_estacao']==id_estacao].copy() 
        for id_estacao in estacoes} 
    for model_number in comparisons.keys()}

metrics_estacoes = {
    model_number:{
        id_estacao:compute_metrics(comparisons_estacoes[model_number][id_estacao]['y_test'],comparisons_estacoes[model_number][id_estacao]['y_pred']) 
        for id_estacao in estacoes} 
    for model_number in comparisons.keys()}

dados = []
for model_number, estacoes_dict in metrics_estacoes.items():
    for id_estacao, metricas in estacoes_dict.items():
        linha = {"model_number": model_number, "id_estacao": id_estacao}
        linha.update(metricas)
        dados.append(linha)

df_metricas = pd.DataFrame(dados)
df_metricas = df_metricas.merge(dim_lat_lon,on='id_estacao',how='left')

# %%
plot_metrica_heatmap(df_metricas, 'R2',model_number=10,figsize=(16,12),markersize=5)

# %% [markdown]
# # ANALISES INDIVIDUAIS

# %%
from comparison_utils import get_all_comparisons,get_metrics_per_station,plot_model_prediction_vs_observation
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
model_numbers = [15]
comparison_df = get_all_comparisons(model_numbers)
count_medicoes_df = comparison_df.groupby(['model','id_estacao'],as_index=False).agg(count_medicoes=('y_test','count'))

metrics_per_station_df = get_metrics_per_station(comparison_df)
metrics_per_station_df = metrics_per_station_df.merge(count_medicoes_df,left_on=['model_number','id_estacao'],right_on=['model','id_estacao'],how='left')

# %%
model_number = 15
min_count_medicoes = 100
metric = 'F1-Score'
ascending = False

metrics_per_station_df.loc[
    (metrics_per_station_df['model_number']==f'model_{model_number}')
    & (metrics_per_station_df['count_medicoes']>=min_count_medicoes)].sort_values(by=metric,ascending=ascending).head()
# Out:
#      model_number  id_estacao  precision    recall  F1-Score      RMSE  \
# 1142     model_15      924223   1.000000  1.000000  1.000000  3.836541
# 1124     model_15      923697   1.000000  1.000000  1.000000  2.244871
# 1061     model_15      921795   0.967949  0.975493  0.971707  1.531268
# 1149     model_15      925050   0.946117  0.961904  0.953946  1.512627
# 1104     model_15      922924   0.931264  0.944930  0.938047  1.458137
#
#             R2       MAE      PSC_A      PCC_A       PMC_A  latitude  \
# 1142  0.613490  1.364722  86.885246  62.500000  100.000000  -21.9833
# 1124  0.933755  0.973483  96.703297  65.217391  100.000000  -21.8333
# 1061  0.980006  0.731712  91.697080  95.415225   98.905109  -19.7667
# 1149  0.969279  0.516704  97.080292  94.976636   98.857143  -22.3333
# 1104  0.979703  0.497727  97.901415  94.736842   95.266272  -20.4167
#
#       longitude     model  count_medicoes
# 1142   -50.1000  model_15             138
# 1124   -46.7500  model_15             114
# 1061   -47.9333  model_15            3348
# 1149   -43.4167  model_15            3322
# 1104   -49.9833  model_15            2866

# %%
metrics_per_station_df.loc[(metrics_per_station_df['model_number']==f'model_{model_number}') & (metrics_per_station_df['R2']>=0),['R2','F1-Score']].corr()
# Out:
#                 R2  F1-Score
# R2        1.000000  0.745428
# F1-Score  0.745428  1.000000

# %%
model_number = 15
id_estacao = 923697
plot_model_prediction_vs_observation(comparison_df, model_number=model_number, id_estacao=id_estacao)

# %%
# Conferir se to validando no lugar correto
# >  Ex: estação 920341 ta com dados desde 2000, nao deveria
# > Testar mais limiares pro bi_model
# > Investigar estçaões do ES
# > Implementar o SmoteR
# > Correlação entre o indice da melhor estação e o R2
